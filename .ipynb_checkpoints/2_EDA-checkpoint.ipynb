# %%
import pandas as pd
from plotnine import ggplot, geom_point, aes, stat_smooth, facet_wrap

# %%
df = pd.read_csv('playlist_features.csv')
df.head()
# Out:
#      Track Name                Track ID    Artist Playlist  danceability  \
# 0    HELICOPTER  2hJS7BdEaH9Jo8MeJujsHT       CLC     KPOP         0.666
# 1  HANN (Alone)  7gr57cYekMWriyJYbT7oZ4  (G)I-DLE     KPOP         0.709
# 2     Oh my god  2DmRXiyn03tOqKgEJXlaiJ  (G)I-DLE     KPOP         0.794
# 3          HWAA  5FiXhM80sP4yg6tEnHkZZn  (G)I-DLE     KPOP         0.384
# 4          LION  40OyiVO9NtBg9R2Gpwxs3u  (G)I-DLE     KPOP         0.741
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.908    5    -2.819     0       0.0560        0.0323          0.000000
# 1   0.718    6    -3.315     0       0.0312        0.0590          0.000000
# 2   0.762    4    -3.525     0       0.0392        0.0358          0.000001
# 3   0.868    6    -3.226     0       0.0711        0.0458          0.000006
# 4   0.715    4    -5.206     0       0.0340        0.0318          0.000000
#
#    liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
print(df.shape)
print("Number of KPOP songs: ", len(df[df['Playlist']=='KPOP']))
print("Number of anime songs: ", len(df[df['Playlist']=='lit anime music']))
# Out:
# (157, 17)
# Number of KPOP songs:  60
# Number of anime songs:  97
